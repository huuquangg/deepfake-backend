# %%
# Built-in
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# TensorFlow / Keras
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, TimeDistributed, GlobalAveragePooling2D, LSTM, Dense, Dropout
)
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Scikit-learn
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
)

# %%
# Define the path to the dataset
base_path = '/Users/admin/AIEngineer/DeepFakeProject/Dataset/Faceplus2'
categories = ['fake', 'real']

# Initialize a list to hold data
data = []

# Process each category
for category in categories:
    category_path = os.path.join(base_path, category)
    for filename in os.listdir(category_path):
        if filename.endswith('.jpg'):
            try:
                id_part, frame_part = filename.split('_frame_')
                id_ = id_part.split('_')[0]
                frame = frame_part.split('.')[0]
                data.append({
                    'filename': filename,
                    'path': os.path.join(category_path, filename),
                    'id': int(id_),
                    'frame': int(frame),
                    'label': category
                })
            except ValueError:
                continue

# Convert the data to a DataFrame
df = pd.DataFrame(data)

# %%
# Đảm bảo đã có df_cropped.csv chứa đường dẫn ảnh đã crop
df['label_id'] = df['label'].map({'fake': 0, 'real': 1})
df
# Out:
#                      filename  \
# 0      596_609_frame_0019.jpg
# 1      746_571_frame_0008.jpg
# 2      514_443_frame_0028.jpg
# 3      642_635_frame_0006.jpg
# 4      937_888_frame_0009.jpg
# ...                       ...
# 59803      727_frame_0009.jpg
# 59804      832_frame_0026.jpg
# 59805      059_frame_0005.jpg
# 59806      572_frame_0008.jpg
# 59807      567_frame_0008.jpg
#
#                                                     path   id  frame label  \
# 0      /Users/admin/AIEngineer/DeepFakeProject/Datase...  596     19  fake
# 1      /Users/admin/AIEngineer/DeepFakeProject/Datase...  746      8  fake
# 2      /Users/admin/AIEngineer/DeepFakeProject/Datase...  514     28  fake
# 3      /Users/admin/AIEngineer/DeepFakeProject/Datase...  642      6  fake
# 4      /Users/admin/AIEngineer/DeepFakeProject/Datase...  937      9  fake
# ...                                                  ...  ...    ...   ...
# 59803  /Users/admin/AIEngineer/DeepFakeProject/Datase...  727      9  real
# 59804  /Users/admin/AIEngineer/DeepFakeProject/Datase...  832     26  real
# 59805  /Users/admin/AIEngineer/DeepFakeProject/Datase...   59      5  real
# 59806  /Users/admin/AIEngineer/DeepFakeProject/Datase...  572      8  real
# 59807  /Users/admin/AIEngineer/DeepFakeProject/Datase...  567      8  real
#
#        label_id
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 59803         1
# 59804         1
# 59805         1
# 59806         1
# 59807         1
#
# [59808 rows x 6 columns]

# %%
df['video_key'] = df['id'].astype(str) + "_" + df['label']

from collections import defaultdict

video_dict = defaultdict(list)
labels = {}

for _, row in df.iterrows():
    key = row['video_key']
    video_dict[key].append(row['path'])
    labels[key] = row['label_id']

# %%
labels
# Out:
# {'596_fake': 0,
#  '746_fake': 0,
#  '514_fake': 0,
#  '642_fake': 0,
#  '937_fake': 0,
#  '0_fake': 0,
#  '241_fake': 0,
#  '174_fake': 0,
#  '308_fake': 0,
#  '348_fake': 0,
#  '793_fake': 0,
#  '961_fake': 0,
#  '991_fake': 0,
#  '653_fake': 0,
#  '341_fake': 0,
#  '304_fake': 0,
#  '687_fake': 0,
#  '719_fake': 0,
#  '90_fake': 0,
#  '38_fake': 0,
#  '827_fake': 0,
#  '605_fake': 0,
#  '454_fake': 0,
#  '244_fake': 0,
#  '418_fake': 0,
#  '4_fake': 0,
#  '538_fake': 0,
#  '79_fake': 0,
#  '128_fake': 0,
#  '146_fake': 0,
#  '766_fake': 0,
#  '155_fake': 0,
#  '579_fake': 0,
#  '581_fake': 0,
#  '692_fake': 0,
#  '580_fake': 0,
#  '898_fake': 0,
#  '641_fake': 0,
#  '171_fake': 0,
#  '737_fake': 0,
#  '832_fake': 0,
#  '337_fake': 0,
#  '510_fake': 0,
#  '879_fake': 0,
#  '408_fake': 0,
#  '143_fake': 0,
#  '487_fake': 0,
#  '865_fake': 0,
#  '73_fake': 0,
#  '682_fake': 0,
#  '287_fake': 0,
#  '743_fake': 0,
#  '922_fake': 0,
#  '407_fake': 0,
#  '133_fake': 0,
#  '850_fake': 0,
#  '234_fake': 0,
#  '478_fake': 0,
#  '325_fake': 0,
#  '840_fake': 0,
#  '886_fake': 0,
#  '611_fake': 0,
#  '125_fake': 0,
#  '797_fake': 0,
#  '302_fake': 0,
#  '985_fake': 0,
#  '184_fake': 0,
#  '530_fake': 0,
#  '617_fake': 0,
#  '391_fake': 0,
#  '138_fake': 0,
#  '368_fake': 0,
#  '897_fake': 0,
#  '522_fake': 0,
#  '652_fake': 0,
#  '871_fake': 0,
#  '558_fake': 0,
#  '520_fake': 0,
#  '329_fake': 0,
#  '179_fake': 0,
#  '116_fake': 0,
#  '721_fake': 0,
#  '738_fake': 0,
#  '962_fake': 0,
#  '851_fake': 0,
#  '648_fake': 0,
#  '994_fake': 0,
#  '161_fake': 0,
#  '365_fake': 0,
#  '841_fake': 0,
#  '66_fake': 0,
#  '327_fake': 0,
#  '242_fake': 0,
#  '696_fake': 0,
#  '131_fake': 0,
#  '172_fake': 0,
#  '110_fake': 0,
#  '655_fake': 0,
#  '88_fake': 0,
#  '141_fake': 0,
#  '725_fake': 0,
#  '995_fake': 0,
#  '361_fake': 0,
#  '629_fake': 0,
#  '870_fake': 0,
#  '608_fake': 0,
#  '15_fake': 0,
#  '226_fake': 0,
#  '56_fake': 0,
#  '387_fake': 0,
#  '513_fake': 0,
#  '401_fake': 0,
#  '235_fake': 0,
#  '130_fake': 0,
#  '31_fake': 0,
#  '660_fake': 0,
#  '99_fake': 0,
#  '532_fake': 0,
#  '357_fake': 0,
#  '893_fake': 0,
#  '637_fake': 0,
#  '414_fake': 0,
#  '973_fake': 0,
#  '105_fake': 0,
#  '720_fake': 0,
#  '799_fake': 0,
#  '463_fake': 0,
#  '759_fake': 0,
#  '72_fake': 0,
#  '821_fake': 0,
#  '964_fake': 0,
#  '824_fake': 0,
#  '419_fake': 0,
#  '713_fake': 0,
#  '710_fake': 0,
#  '576_fake': 0,
#  '722_fake': 0,
#  '633_fake': 0,
#  '48_fake': 0,
#  '664_fake': 0,
#  '709_fake': 0,
#  '246_fake': 0,
#  '516_fake': 0,
#  '382_fake': 0,
#  '978_fake': 0,
#  '919_fake': 0,
#  '945_fake': 0,
#  '589_fake': 0,
#  '458_fake': 0,
#  '753_fake': 0,
#  '210_fake': 0,
#  '255_fake': 0,
#  '674_fake': 0,
#  '127_fake': 0,
#  '809_fake': 0,
#  '249_fake': 0,
#  '765_fake': 0,
#  '208_fake': 0,
#  '549_fake': 0,
#  '27_fake': 0,
#  '857_fake': 0,
#  '475_fake': 0,
#  '972_fake': 0,
#  '425_fake': 0,
#  '776_fake': 0,
#  '222_fake': 0,
#  '129_fake': 0,
#  '11_fake': 0,
#  '107_fake': 0,
#  '528_fake': 0,
#  '575_fake': 0,
#  '671_fake': 0,
#  '340_fake': 0,
#  '907_fake': 0,
#  '965_fake': 0,
#  '631_fake': 0,
#  '836_fake': 0,
#  '109_fake': 0,
#  '990_fake': 0,
#  '76_fake': 0,
#  '46_fake': 0,
#  '406_fake': 0,
#  '34_fake': 0,
#  '602_fake': 0,
#  '285_fake': 0,
#  '318_fake': 0,
#  '262_fake': 0,
#  '240_fake': 0,
#  '353_fake': 0,
#  '693_fake': 0,
#  '492_fake': 0,
#  '680_fake': 0,
#  '704_fake': 0,
#  '190_fake': 0,
#  '230_fake': 0,
#  '9_fake': 0,
#  '104_fake': 0,
#  '323_fake': 0,
#  '301_fake': 0,
#  '434_fake': 0,
#  '86_fake': 0,
#  '36_fake': 0,
#  '13_fake': 0,
#  '772_fake': 0,
#  '465_fake': 0,
#  '270_fake': 0,
#  '273_fake': 0,
#  '952_fake': 0,
#  '763_fake': 0,
#  '878_fake': 0,
#  '889_fake': 0,
#  '193_fake': 0,
#  '64_fake': 0,
#  '944_fake': 0,
#  '758_fake': 0,
#  '557_fake': 0,
#  '876_fake': 0,
#  '30_fake': 0,
#  '860_fake': 0,
#  '835_fake': 0,
#  '26_fake': 0,
#  '997_fake': 0,
#  '321_fake': 0,
#  '247_fake': 0,
#  '291_fake': 0,
#  '376_fake': 0,
#  '571_fake': 0,
#  '724_fake': 0,
#  '448_fake': 0,
#  '920_fake': 0,
#  '837_fake': 0,
#  '447_fake': 0,
#  '854_fake': 0,
#  '68_fake': 0,
#  '232_fake': 0,
#  '352_fake': 0,
#  '924_fake': 0,
#  '428_fake': 0,
#  '346_fake': 0,
#  '902_fake': 0,
#  '169_fake': 0,
#  '684_fake': 0,
#  '890_fake': 0,
#  '794_fake': 0,
#  '39_fake': 0,
#  '825_fake': 0,
#  '381_fake': 0,
#  '730_fake': 0,
#  '735_fake': 0,
#  '10_fake': 0,
#  '607_fake': 0,
#  '798_fake': 0,
#  '436_fake': 0,
#  '928_fake': 0,
#  '292_fake': 0,
#  '71_fake': 0,
#  '778_fake': 0,
#  '762_fake': 0,
#  '317_fake': 0,
#  '591_fake': 0,
#  '400_fake': 0,
#  '112_fake': 0,
#  '351_fake': 0,
#  '504_fake': 0,
#  '560_fake': 0,
#  '342_fake': 0,
#  '587_fake': 0,
#  '96_fake': 0,
#  '813_fake': 0,
#  '197_fake': 0,
#  '347_fake': 0,
#  '394_fake': 0,
#  '494_fake': 0,
#  '474_fake': 0,
#  '676_fake': 0,
#  '281_fake': 0,
#  '932_fake': 0,
#  '384_fake': 0,
#  '942_fake': 0,
#  '459_fake': 0,
#  '923_fake': 0,
#  '892_fake': 0,
#  '261_fake': 0,
#  '374_fake': 0,
#  '156_fake': 0,
#  '749_fake': 0,
#  '828_fake': 0,
#  '955_fake': 0,
#  '610_fake': 0,
#  '909_fake': 0,
#  '439_fake': 0,
#  '509_fake': 0,
#  '360_fake': 0,
#  '887_fake': 0,
#  '708_fake': 0,
#  '228_fake': 0,
#  '192_fake': 0,
#  '409_fake': 0,
#  '833_fake': 0,
#  '215_fake': 0,
#  '380_fake': 0,
#  '328_fake': 0,
#  '148_fake': 0,
#  '628_fake': 0,
#  '815_fake': 0,
#  '773_fake': 0,
#  '137_fake': 0,
#  '63_fake': 0,
#  '934_fake': 0,
#  '685_fake': 0,
#  '182_fake': 0,
#  '151_fake': 0,
#  '669_fake': 0,
#  '430_fake': 0,
#  '113_fake': 0,
#  '417_fake': 0,
#  '415_fake': 0,
#  '377_fake': 0,
#  '695_fake': 0,
#  '598_fake': 0,
#  '760_fake': 0,
#  '245_fake': 0,
#  '124_fake': 0,
#  '267_fake': 0,
#  '550_fake': 0,
#  '888_fake': 0,
#  '542_fake': 0,
#  '118_fake': 0,
#  '915_fake': 0,
#  '654_fake': 0,
#  '852_fake': 0,
#  '971_fake': 0,
#  '78_fake': 0,
#  '574_fake': 0,
#  '588_fake': 0,
#  '307_fake': 0,
#  '545_fake': 0,
#  '900_fake': 0,
#  '330_fake': 0,
#  '703_fake': 0,
#  '936_fake': 0,
#  '209_fake': 0,
#  '491_fake': 0,
#  '917_fake': 0,
#  '354_fake': 0,
#  '986_fake': 0,
#  '554_fake': 0,
#  '367_fake': 0,
#  '844_fake': 0,
#  '423_fake': 0,
#  '69_fake': 0,
#  '55_fake': 0,
#  '195_fake': 0,
#  '263_fake': 0,
#  '780_fake': 0,
#  '732_fake': 0,
#  '847_fake': 0,
#  '845_fake': 0,
#  '248_fake': 0,
#  '638_fake': 0,
#  '661_fake': 0,
#  '157_fake': 0,
#  '769_fake': 0,
#  '500_fake': 0,
#  '884_fake': 0,
#  '590_fake': 0,
#  '440_fake': 0,
#  '288_fake': 0,
#  '691_fake': 0,
#  '805_fake': 0,
#  '412_fake': 0,
#  '597_fake': 0,
#  '201_fake': 0,
#  '349_fake': 0,
#  '838_fake': 0,
#  '82_fake': 0,
#  '142_fake': 0,
#  '511_fake': 0,
#  '698_fake': 0,
#  '152_fake': 0,
#  '481_fake': 0,
#  '606_fake': 0,
#  '57_fake': 0,
#  '804_fake': 0,
#  '472_fake': 0,
#  '853_fake': 0,
#  '220_fake': 0,
#  '612_fake': 0,
#  '358_fake': 0,
#  '132_fake': 0,
#  '150_fake': 0,
#  '935_fake': 0,
#  '264_fake': 0,
#  '426_fake': 0,
#  '864_fake': 0,
#  '981_fake': 0,
#  '747_fake': 0,
#  '578_fake': 0,
#  '437_fake': 0,
#  '750_fake': 0,
#  '858_fake': 0,
#  '32_fake': 0,
#  '736_fake': 0,
#  '582_fake': 0,
#  '614_fake': 0,
#  '707_fake': 0,
#  '252_fake': 0,
#  '700_fake': 0,
#  '265_fake': 0,
#  '950_fake': 0,
#  '45_fake': 0,
#  '429_fake': 0,
#  '49_fake': 0,
#  '81_fake': 0,
#  '42_fake': 0,
#  '943_fake': 0,
#  '370_fake': 0,
#  '300_fake': 0,
#  '830_fake': 0,
#  '390_fake': 0,
#  '123_fake': 0,
#  '861_fake': 0,
#  '457_fake': 0,
#  '95_fake': 0,
#  '506_fake': 0,
#  '134_fake': 0,
#  '515_fake': 0,
#  '350_fake': 0,
#  '912_fake': 0,
#  '286_fake': 0,
#  '47_fake': 0,
#  '880_fake': 0,
#  '752_fake': 0,
#  '219_fake': 0,
#  '216_fake': 0,
#  '518_fake': 0,
#  '111_fake': 0,
#  '484_fake': 0,
#  '767_fake': 0,
#  '188_fake': 0,
#  '875_fake': 0,
#  '976_fake': 0,
#  '584_fake': 0,
#  '823_fake': 0,
#  '647_fake': 0,
#  '634_fake': 0,
#  '748_fake': 0,
#  '989_fake': 0,
#  '967_fake': 0,
#  '499_fake': 0,
#  '65_fake': 0,
#  '33_fake': 0,
#  '207_fake': 0,
#  '100_fake': 0,
#  '697_fake': 0,
#  '147_fake': 0,
#  '121_fake': 0,
#  '371_fake': 0,
#  '206_fake': 0,
#  '834_fake': 0,
#  '52_fake': 0,
#  '324_fake': 0,
#  '344_fake': 0,
#  '688_fake': 0,
#  '191_fake': 0,
#  '536_fake': 0,
#  '339_fake': 0,
#  '490_fake': 0,
#  '694_fake': 0,
#  '8_fake': 0,
#  '54_fake': 0,
#  '974_fake': 0,
#  '609_fake': 0,
#  '91_fake': 0,
#  '553_fake': 0,
#  '656_fake': 0,
#  '432_fake': 0,
#  '62_fake': 0,
#  '566_fake': 0,
#  '225_fake': 0,
#  '362_fake': 0,
#  '253_fake': 0,
#  '120_fake': 0,
#  '175_fake': 0,
#  '543_fake': 0,
#  '812_fake': 0,
#  '842_fake': 0,
#  '555_fake': 0,
#  '59_fake': 0,
#  '843_fake': 0,
#  '562_fake': 0,
#  '108_fake': 0,
#  '498_fake': 0,
#  '873_fake': 0,
#  '405_fake': 0,
#  '817_fake': 0,
#  '85_fake': 0,
#  '160_fake': 0,
#  '826_fake': 0,
#  '214_fake': 0,
#  '453_fake': 0,
#  '657_fake': 0,
#  '24_fake': 0,
#  '114_fake': 0,
#  '92_fake': 0,
#  '751_fake': 0,
#  '153_fake': 0,
#  '800_fake': 0,
#  '224_fake': 0,
#  '855_fake': 0,
#  '202_fake': 0,
#  '677_fake': 0,
#  '393_fake': 0,
#  '471_fake': 0,
#  '600_fake': 0,
#  '198_fake': 0,
#  '745_fake': 0,
#  '930_fake': 0,
#  '74_fake': 0,
#  '106_fake': 0,
#  '378_fake': 0,
#  '404_fake': 0,
#  '250_fake': 0,
#  '940_fake': 0,
#  '470_fake': 0,
#  '910_fake': 0,
#  '115_fake': 0,
#  '839_fake': 0,
#  '531_fake': 0,
#  '635_fake': 0,
#  '410_fake': 0,
#  '761_fake': 0,
#  '630_fake': 0,
#  '266_fake': 0,
#  '512_fake': 0,
#  '734_fake': 0,
#  '573_fake': 0,
#  '702_fake': 0,
#  '477_fake': 0,
#  '254_fake': 0,
#  '829_fake': 0,
#  '820_fake': 0,
#  '786_fake': 0,
#  '525_fake': 0,
#  '651_fake': 0,
#  '849_fake': 0,
#  '527_fake': 0,
#  '699_fake': 0,
#  '444_fake': 0,
#  '144_fake': 0,
#  '785_fake': 0,
#  '467_fake': 0,
#  '822_fake': 0,
#  '212_fake': 0,
#  '963_fake': 0,
#  '312_fake': 0,
#  '17_fake': 0,
#  '119_fake': 0,
#  '449_fake': 0,
#  '792_fake': 0,
#  '388_fake': 0,
#  '176_fake': 0,
#  '145_fake': 0,
#  '218_fake': 0,
#  '41_fake': 0,
#  '165_fake': 0,
#  '918_fake': 0,
#  '988_fake': 0,
#  '718_fake': 0,
#  '595_fake': 0,
#  '774_fake': 0,
#  '621_fake': 0,
#  '645_fake': 0,
#  '97_fake': 0,
#  '488_fake': 0,
#  '6_fake': 0,
#  '431_fake': 0,
#  '592_fake': 0,
#  '987_fake': 0,
#  '586_fake': 0,
#  '139_fake': 0,
#  '258_fake': 0,
#  '203_fake': 0,
#  '313_fake': 0,
#  '905_fake': 0,
#  '43_fake': 0,
#  '782_fake': 0,
#  '420_fake': 0,
#  '620_fake': 0,
#  '199_fake': 0,
#  '908_fake': 0,
#  '771_fake': 0,
#  '77_fake': 0,
#  '881_fake': 0,
#  '58_fake': 0,
#  '966_fake': 0,
#  '993_fake': 0,
#  '904_fake': 0,
#  '802_fake': 0,
#  '168_fake': 0,
#  '489_fake': 0,
#  '958_fake': 0,
#  '167_fake': 0,
#  '819_fake': 0,
#  '309_fake': 0,
#  '502_fake': 0,
#  '456_fake': 0,
#  '136_fake': 0,
#  '733_fake': 0,
#  '956_fake': 0,
#  '364_fake': 0,
#  '933_fake': 0,
#  '294_fake': 0,
#  '539_fake': 0,
#  '701_fake': 0,
#  '399_fake': 0,
#  '885_fake': 0,
#  '856_fake': 0,
#  '476_fake': 0,
#  '421_fake': 0,
#  '567_fake': 0,
#  '619_fake': 0,
#  '559_fake': 0,
#  '859_fake': 0,
#  '568_fake': 0,
#  '686_fake': 0,
#  '385_fake': 0,
#  '464_fake': 0,
#  '299_fake': 0,
#  '646_fake': 0,
#  '505_fake': 0,
#  '906_fake': 0,
#  '984_fake': 0,
#  '280_fake': 0,
#  '872_fake': 0,
#  '451_fake': 0,
#  '790_fake': 0,
#  '25_fake': 0,
#  '102_fake': 0,
#  '211_fake': 0,
#  '275_fake': 0,
#  '103_fake': 0,
#  '705_fake': 0,
#  '493_fake': 0,
#  '271_fake': 0,
#  '616_fake': 0,
#  '711_fake': 0,
#  '402_fake': 0,
#  '848_fake': 0,
#  '877_fake': 0,
#  '290_fake': 0,
#  '659_fake': 0,
#  '383_fake': 0,
#  '22_fake': 0,
#  '941_fake': 0,
#  '427_fake': 0,
#  '162_fake': 0,
#  '911_fake': 0,
#  '403_fake': 0,
#  '563_fake': 0,
#  '122_fake': 0,
#  '183_fake': 0,
#  '927_fake': 0,
#  '529_fake': 0,
#  '411_fake': 0,
#  '808_fake': 0,
#  '519_fake': 0,
#  '783_fake': 0,
#  '460_fake': 0,
#  '577_fake': 0,
#  '818_fake': 0,
#  '723_fake': 0,
#  '293_fake': 0,
#  '533_fake': 0,
#  '149_fake': 0,
#  '468_fake': 0,
#  '306_fake': 0,
#  '450_fake': 0,
#  '585_fake': 0,
#  '333_fake': 0,
#  '483_fake': 0,
#  '1_fake': 0,
#  '485_fake': 0,
#  '239_fake': 0,
#  '29_fake': 0,
#  '756_fake': 0,
#  '954_fake': 0,
#  '862_fake': 0,
#  '392_fake': 0,
#  '678_fake': 0,
#  '229_fake': 0,
#  '433_fake': 0,
#  '60_fake': 0,
#  '899_fake': 0,
#  '957_fake': 0,
#  '315_fake': 0,
#  '561_fake': 0,
#  '297_fake': 0,
#  '741_fake': 0,
#  '716_fake': 0,
#  '891_fake': 0,
#  '706_fake': 0,
#  '672_fake': 0,
#  '386_fake': 0,
#  '23_fake': 0,
#  '866_fake': 0,
#  '622_fake': 0,
#  '731_fake': 0,
#  '187_fake': 0,
#  '649_fake': 0,
#  '501_fake': 0,
#  '883_fake': 0,
#  '28_fake': 0,
#  '274_fake': 0,
#  '916_fake': 0,
#  '260_fake': 0,
#  '959_fake': 0,
#  '486_fake': 0,
#  '200_fake': 0,
#  '89_fake': 0,
#  '166_fake': 0,
#  '159_fake': 0,
#  '311_fake': 0,
#  '938_fake': 0,
#  '679_fake': 0,
#  '356_fake': 0,
#  '366_fake': 0,
#  '992_fake': 0,
#  '482_fake': 0,
#  '163_fake': 0,
#  '604_fake': 0,
#  '338_fake': 0,
#  '359_fake': 0,
#  '914_fake': 0,
#  '217_fake': 0,
#  '178_fake': 0,
#  '895_fake': 0,
#  '784_fake': 0,
#  '373_fake': 0,
#  '636_fake': 0,
#  '618_fake': 0,
#  '868_fake': 0,
#  '466_fake': 0,
#  '181_fake': 0,
#  '795_fake': 0,
#  '322_fake': 0,
#  '541_fake': 0,
#  '544_fake': 0,
#  '21_fake': 0,
#  '788_fake': 0,
#  '238_fake': 0,
#  '946_fake': 0,
#  '846_fake': 0,
#  '336_fake': 0,
#  '650_fake': 0,
#  '717_fake': 0,
#  '925_fake': 0,
#  '624_fake': 0,
#  '479_fake': 0,
#  '681_fake': 0,
#  '7_fake': 0,
#  '831_fake': 0,
#  '740_fake': 0,
#  '503_fake': 0,
#  '768_fake': 0,
#  '816_fake': 0,
#  '537_fake': 0,
#  '626_fake': 0,
#  '279_fake': 0,
#  '173_fake': 0,
#  '186_fake': 0,
#  '469_fake': 0,
#  '627_fake': 0,
#  '948_fake': 0,
#  '237_fake': 0,
#  '40_fake': 0,
#  '507_fake': 0,
#  '20_fake': 0,
#  '789_fake': 0,
#  '154_fake': 0,
#  '84_fake': 0,
#  '213_fake': 0,
#  '777_fake': 0,
#  '546_fake': 0,
#  '16_fake': 0,
#  '442_fake': 0,
#  '462_fake': 0,
#  '999_fake': 0,
#  '663_fake': 0,
#  '269_fake': 0,
#  '35_fake': 0,
#  '781_fake': 0,
#  '810_fake': 0,
#  '601_fake': 0,
#  '742_fake': 0,
#  '508_fake': 0,
#  '975_fake': 0,
#  '960_fake': 0,
#  '744_fake': 0,
#  '277_fake': 0,
#  '53_fake': 0,
#  '548_fake': 0,
#  '204_fake': 0,
#  '593_fake': 0,
#  '615_fake': 0,
#  '278_fake': 0,
#  '424_fake': 0,
#  '775_fake': 0,
#  '497_fake': 0,
#  '814_fake': 0,
#  '87_fake': 0,
#  '94_fake': 0,
#  '556_fake': 0,
#  '51_fake': 0,
#  '977_fake': 0,
#  '12_fake': 0,
#  '882_fake': 0,
#  '901_fake': 0,
#  '770_fake': 0,
#  '951_fake': 0,
#  '18_fake': 0,
#  '389_fake': 0,
#  '603_fake': 0,
#  '540_fake': 0,
#  '135_fake': 0,
#  '668_fake': 0,
#  '521_fake': 0,
#  '867_fake': 0,
#  '931_fake': 0,
#  '396_fake': 0,
#  '583_fake': 0,
#  '251_fake': 0,
#  '643_fake': 0,
#  '243_fake': 0,
#  '185_fake': 0,
#  '369_fake': 0,
#  '314_fake': 0,
#  '37_fake': 0,
#  '413_fake': 0,
#  '256_fake': 0,
#  '726_fake': 0,
#  '272_fake': 0,
#  '874_fake': 0,
#  '282_fake': 0,
#  '757_fake': 0,
#  '526_fake': 0,
#  '939_fake': 0,
#  '764_fake': 0,
#  '257_fake': 0,
#  '284_fake': 0,
#  '929_fake': 0,
#  '755_fake': 0,
#  '395_fake': 0,
#  '473_fake': 0,
#  '372_fake': 0,
#  '61_fake': 0,
#  '779_fake': 0,
#  '259_fake': 0,
#  '180_fake': 0,
#  '982_fake': 0,
#  '683_fake': 0,
#  '375_fake': 0,
#  '979_fake': 0,
#  '101_fake': 0,
#  '177_fake': 0,
#  '712_fake': 0,
#  '93_fake': 0,
#  '983_fake': 0,
#  '787_fake': 0,
#  '998_fake': 0,
#  '673_fake': 0,
#  '332_fake': 0,
#  '729_fake': 0,
#  '565_fake': 0,
#  '227_fake': 0,
#  '863_fake': 0,
#  '298_fake': 0,
#  '320_fake': 0,
#  '14_fake': 0,
#  '268_fake': 0,
#  '379_fake': 0,
#  '363_fake': 0,
#  '296_fake': 0,
#  '295_fake': 0,
#  '727_fake': 0,
#  '334_fake': 0,
#  '443_fake': 0,
#  '67_fake': 0,
#  '894_fake': 0,
#  '438_fake': 0,
#  '658_fake': 0,
#  '869_fake': 0,
#  '126_fake': 0,
#  '189_fake': 0,
#  '455_fake': 0,
#  '644_fake': 0,
#  '613_fake': 0,
#  '441_fake': 0,
#  '495_fake': 0,
#  '70_fake': 0,
#  '289_fake': 0,
#  '196_fake': 0,
#  '801_fake': 0,
#  '599_fake': 0,
#  '969_fake': 0,
#  '796_fake': 0,
#  '236_fake': 0,
#  '194_fake': 0,
#  '335_fake': 0,
#  '117_fake': 0,
#  '714_fake': 0,
#  '594_fake': 0,
#  '98_fake': 0,
#  '639_fake': 0,
#  '524_fake': 0,
#  '170_fake': 0,
#  '343_fake': 0,
#  '662_fake': 0,
#  '3_fake': 0,
#  '75_fake': 0,
#  '461_fake': 0,
#  '445_fake': 0,
#  '355_fake': 0,
#  '398_fake': 0,
#  '996_fake': 0,
#  '496_fake': 0,
#  '140_fake': 0,
#  '623_fake': 0,
#  '276_fake': 0,
#  '446_fake': 0,
#  '715_fake': 0,
#  '625_fake': 0,
#  '806_fake': 0,
#  '921_fake': 0,
#  '926_fake': 0,
#  '903_fake': 0,
#  '689_fake': 0,
#  '913_fake': 0,
#  '640_fake': 0,
#  '754_fake': 0,
#  '233_fake': 0,
#  '19_fake': 0,
#  '535_fake': 0,
#  '632_fake': 0,
#  '896_fake': 0,
#  '670_fake': 0,
#  '572_fake': 0,
#  '221_fake': 0,
#  '223_fake': 0,
#  '728_fake': 0,
#  '205_fake': 0,
#  '552_fake': 0,
#  '83_fake': 0,
#  '980_fake': 0,
#  '164_fake': 0,
#  '551_fake': 0,
#  '345_fake': 0,
#  '517_fake': 0,
#  '523_fake': 0,
#  '283_fake': 0,
#  '675_fake': 0,
#  '326_fake': 0,
#  '970_fake': 0,
#  '303_fake': 0,
#  '319_fake': 0,
#  '666_fake': 0,
#  '480_fake': 0,
#  '397_fake': 0,
#  '803_fake': 0,
#  '570_fake': 0,
#  '2_fake': 0,
#  '949_fake': 0,
#  '331_fake': 0,
#  '534_fake': 0,
#  '791_fake': 0,
#  '231_fake': 0,
#  '158_fake': 0,
#  '807_fake': 0,
#  '44_fake': 0,
#  '947_fake': 0,
#  '80_fake': 0,
#  '564_fake': 0,
#  '667_fake': 0,
#  '422_fake': 0,
#  '811_fake': 0,
#  '968_fake': 0,
#  '316_fake': 0,
#  '305_fake': 0,
#  '665_fake': 0,
#  '953_fake': 0,
#  '435_fake': 0,
#  '5_fake': 0,
#  '690_fake': 0,
#  '739_fake': 0,
#  '310_fake': 0,
#  '50_fake': 0,
#  '416_fake': 0,
#  '569_fake': 0,
#  '452_fake': 0,
#  '547_fake': 0,
#  ...}

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/envs/environment_tf_216/lib/python3.9/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.0 in /opt/anaconda3/envs/environment_tf_216/lib/python3.9/site-packages (from opencv-python) (1.26.4)

# %%
# Chuẩn bị dữ liệu
video_keys = list(video_dict.keys())
video_labels = [labels[k] for k in video_keys]

# Cấu hình
img_size = (224, 224)
batch_size = 16
epochs = 50
n_splits = 5
sequence_len = 10
results = []
all_histories = []

# Custom data generator để nạp chuỗi ảnh từ video_dict
class VideoSequence(tf.keras.utils.Sequence):
    def __init__(self, video_keys, video_dict, labels, batch_size, img_size, sequence_len=10, augment=False):
        self.video_keys = video_keys
        self.video_dict = video_dict
        self.labels = labels
        self.batch_size = batch_size
        self.img_size = img_size
        self.sequence_len = sequence_len
        self.augment = augment
        self.datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=15 if augment else 0,
            zoom_range=0.1 if augment else 0,
            horizontal_flip=augment
        )

    def __len__(self):
        return int(np.ceil(len(self.video_keys) / self.batch_size))

    def __getitem__(self, idx):
        batch_keys = self.video_keys[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_X, batch_y = [], []

        for key in batch_keys:
            frames = video_dict[key][:self.sequence_len]
            imgs = []
            for path in frames:
                img = cv2.imread(path)
                img = cv2.resize(img, self.img_size)
                img = self.datagen.random_transform(img) if self.augment else img
                img = img.astype('float32') / 255.0
                imgs.append(img)
            while len(imgs) < self.sequence_len:
                imgs.append(np.zeros((*self.img_size, 3), dtype='float32'))  # padding
            batch_X.append(imgs)
            batch_y.append(self.labels[key])

        return np.array(batch_X), np.array(batch_y)

# Hàm xây dựng mô hình
def build_model(sequence_len, img_size):
    base_cnn = MobileNetV2(input_shape=(*img_size, 3), include_top=False, weights='imagenet')

    # Freeze toàn bộ backbone để giảm overfit
    base_cnn.trainable = False

    # CNN feature extractor
    cnn_out = GlobalAveragePooling2D()(base_cnn.output)
    cnn_model = Model(inputs=base_cnn.input, outputs=cnn_out)

    # Sequence input
    input_seq = Input(shape=(sequence_len, *img_size, 3))
    x = TimeDistributed(cnn_model)(input_seq)

    # LSTM đơn giản hơn
    x = LSTM(64, return_sequences=False)(x)
    x = Dropout(0.5)(x)

    # Không dùng nhiều Dense, chỉ một đầu ra
    output = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=input_seq, outputs=output)
    return model

# K-Fold huấn luyện
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

for fold, (trainval_idx, test_idx) in enumerate(skf.split(video_keys, video_labels), 1):
    print(f"\n===== Fold {fold} =====")

    trainval_keys = [video_keys[i] for i in trainval_idx]
    test_keys = [video_keys[i] for i in test_idx]

    y_trainval = [labels[k] for k in trainval_keys]
    train_keys, val_keys = train_test_split(trainval_keys, test_size=0.1, stratify=y_trainval, random_state=fold)

    train_gen = VideoSequence(train_keys, video_dict, labels, batch_size, img_size, sequence_len, augment=True)
    val_gen   = VideoSequence(val_keys, video_dict, labels, batch_size, img_size, sequence_len, augment=False)
    test_gen  = VideoSequence(test_keys, video_dict, labels, batch_size, img_size, sequence_len, augment=False)

    model = build_model(sequence_len, img_size)
    model.compile(optimizer=Adamax(1e-4), loss='binary_crossentropy', metrics=['accuracy'])

    model_path = f"best_model_fold{fold}.h5"
    checkpoint = ModelCheckpoint(model_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
    earlystop = EarlyStopping(monitor='val_accuracy', patience=4, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6)

    history = model.fit(train_gen, validation_data=val_gen,
                        epochs=epochs, callbacks=[checkpoint, earlystop, reduce_lr], verbose=1)

    all_histories.append(history.history)

    model.load_weights(model_path)

    y_true = [labels[k] for k in test_keys]
    y_pred_prob = model.predict(test_gen).ravel()
    y_pred = (y_pred_prob > 0.5).astype(int)

    results.append({
        'fold': fold,
        'accuracy': accuracy_score(y_true, y_pred),
        'precision': precision_score(y_true, y_pred),
        'recall': recall_score(y_true, y_pred),
        'f1': f1_score(y_true, y_pred),
        'auc': roc_auc_score(y_true, y_pred_prob)
    })

# Tổng kết kết quả
print("\n📊 Tổng kết kết quả các fold:")
for r in results:
    print(f"Fold {r['fold']}: Accuracy={r['accuracy']:.4f}, F1={r['f1']:.4f}, AUC={r['auc']:.4f}")
# Out:
# ===== Fold 1 =====
# 2025-08-08 12:33:13.053683: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4
# 2025-08-08 12:33:13.053720: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-08-08 12:33:13.053728: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2025-08-08 12:33:13.053889: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-08-08 12:33:13.054026: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.

# %%
results_df = pd.DataFrame(results)
print("📊 Kết quả trung bình:")
print(results_df.mean(numeric_only=True))
results_df

# %%
for i, hist in enumerate(all_histories, 1):
    plt.figure()
    plt.plot(hist['accuracy'], label='Train Acc')
    plt.plot(hist['val_accuracy'], label='Val Acc')
    plt.title(f'Fold {i} Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()

    plt.figure()
    plt.plot(hist['loss'], label='Train Loss')
    plt.plot(hist['val_loss'], label='Val Loss')
    plt.title(f'Fold {i} Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Save mô hình fold cuối cùng
model.save("mobilenetv2_faceplus_final.h5")

# %%
import pandas as pd

# Giả sử results đã có và bạn đã tạo results_df
results_df = pd.DataFrame(results)

# Tính các chỉ số
accuracy_mean = results_df['accuracy'].mean()
accuracy_std = results_df['accuracy'].std()  # dùng sample std (chia cho n-1)
accuracy_range = results_df['accuracy'].max() - results_df['accuracy'].min()
accuracy_cv_percent = (accuracy_std / accuracy_mean) * 100

# In kết quả
print("📊 Kết quả trung bình:")
print(results_df.mean(numeric_only=True))

print(f"\n✅ CV Accuracy (Mean Accuracy): {accuracy_mean:.4f}")
print(f"📈 Range Accuracy: {accuracy_range:.4f}")
print(f"📉 Accuracy CV% (std/mean): {accuracy_cv_percent:.2f}%")

# Hiển thị bảng kết quả nếu cần
results_df
